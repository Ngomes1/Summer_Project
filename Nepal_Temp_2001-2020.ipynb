# %%
import sys
import numpy as np
import xarray as xr
import pandas as pd
import csv
import matplotlib
import matplotlib.pyplot as plt

# %%
fp = 'cru_ts4.05.2001.2010.tmp.dat.nc.gz'

temp_data = xr.open_dataset(fp)

nepal_temp = temp_data.loc[dict(lat=slice(26,28), lon=slice(80.5,88))]

print(nepal_temp)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 4, lon: 15, time: 120)
# Coordinates:
#   * lon      (lon) float32 80.75 81.25 81.75 82.25 ... 86.25 86.75 87.25 87.75
#   * lat      (lat) float32 26.25 26.75 27.25 27.75
#   * time     (time) datetime64[ns] 2001-01-16 2001-02-15 ... 2010-12-16
# Data variables:
#     tmp      (time, lat, lon) float32 ...
#     stn      (time, lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.05 Mean Temperature
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2103051243. Data generated from:tmp.2103041709.dtb
#     history:      Fri  5 Mar 13:25:53 GMT 2021 : User harry : Program makegri...
#     references:   Information on the data is available at http://badc.nerc.ac...
#     comment:      Access to these data is available to any registered CEDA user.
#     contact:      support@ceda.ac.uk

# %%
chitwan_temp = nepal_temp.loc[dict(lat = 27.75, lon = 84.25 )]

print(chitwan_temp)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 120)
# Coordinates:
#     lon      float32 84.25
#     lat      float32 27.75
#   * time     (time) datetime64[ns] 2001-01-16 2001-02-15 ... 2010-12-16
# Data variables:
#     tmp      (time) float32 ...
#     stn      (time) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.05 Mean Temperature
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2103051243. Data generated from:tmp.2103041709.dtb
#     history:      Fri  5 Mar 13:25:53 GMT 2021 : User harry : Program makegri...
#     references:   Information on the data is available at http://badc.nerc.ac...
#     comment:      Access to these data is available to any registered CEDA user.
#     contact:      support@ceda.ac.uk

# %%
years = 10 

temp_annual = np.zeros(years)

for year in range(years):
    
    start_index = year * 12 + 3 
    end_index = (year + 1) * 12
    
    temp_annual[year] = chitwan_temp['tmp'][start_index:end_index].mean()
    
    
print(temp_annual)
np.save('temp_annual.npy', temp_annual)
# Out:
# [25.25555801 25.33333397 25.39999962 25.38888931 25.21111107 25.36666679
#  25.68888855 25.13333511 25.77777863 26.11111069]

# %%
f, ax = plt.subplots()

x = np.arange(2001, 2011, 1)
y = temp_annual

ax.set_xlabel('Year')
ax.set_ylabel('Mean Annual Temp ($^0$C)')
ax.plot(x, temp_annual)

#plt.show()
plt.savefig('temperature')
print(temp_annual[4])
# Out:
# 23.58333396911621

# %%
fp2 = 'cru_ts4.05.2011.2020.tmp.dat.nc.gz'

temp_data2 = xr.open_dataset(fp2)

nepal_temp2 = temp_data2.loc[dict(lat=slice(26,28), lon=slice(80.5,88))]

print(nepal_temp2)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 4, lon: 15, time: 120)
# Coordinates:
#   * lon      (lon) float32 80.75 81.25 81.75 82.25 ... 86.25 86.75 87.25 87.75
#   * lat      (lat) float32 26.25 26.75 27.25 27.75
#   * time     (time) datetime64[ns] 2011-01-16 2011-02-15 ... 2020-12-16
# Data variables:
#     tmp      (time, lat, lon) float32 ...
#     stn      (time, lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.05 Mean Temperature
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2103051243. Data generated from:tmp.2103041709.dtb
#     history:      Fri  5 Mar 13:25:53 GMT 2021 : User harry : Program makegri...
#     references:   Information on the data is available at http://badc.nerc.ac...
#     comment:      Access to these data is available to any registered CEDA user.
#     contact:      support@ceda.ac.uk

# %%
chitwan_temp2 = nepal_temp2.loc[dict(lat = 27.75, lon = 84.25 )]

print(chitwan_temp2)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 120)
# Coordinates:
#     lon      float32 84.25
#     lat      float32 27.75
#   * time     (time) datetime64[ns] 2011-01-16 2011-02-15 ... 2020-12-16
# Data variables:
#     tmp      (time) float32 ...
#     stn      (time) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.05 Mean Temperature
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2103051243. Data generated from:tmp.2103041709.dtb
#     history:      Fri  5 Mar 13:25:53 GMT 2021 : User harry : Program makegri...
#     references:   Information on the data is available at http://badc.nerc.ac...
#     comment:      Access to these data is available to any registered CEDA user.
#     contact:      support@ceda.ac.uk

# %%
years2 = 10 

temp_annual2 = np.zeros(years2)

for year in range(years2):
    
    start_index2 = year * 12
    end_index2 = (year + 1) * 12
    
    temp_annual2[year] = chitwan_temp2['tmp'][start_index2:end_index2].mean()
    
    
print(temp_annual2)
np.save('temp_annual2.npy', temp_annual2)
# Out:
# [23.45000267 23.36666679 23.21666718 23.30000114 23.35833549 24.05833244
#  23.78333092 23.47500038 23.31666756 23.12500191]

# %%
f, ax = plt.subplots()

x = np.arange(2011, 2021, 1)
y = temp_annual2

ax.set_xlabel('Year')
ax.set_ylabel('Mean Annual Temp ($^0$C)')
ax.plot(x, temp_annual2)

plt.show()

# %%
import sys
#!{sys.executable} -m pip install netCDF4
#!{sys.executable} -m pip install numpy --upgrade
#!{sys.executable} -m pip install xarray
# !{sys.executable} -m pip install scipy --upgrade
import numpy as np
import xarray as xr
import pandas as pd
import csv
import matplotlib
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: scipy in c:\users\nicho\anaconda3\lib\site-packages (1.6.2)
# Collecting scipy
#   Downloading scipy-1.7.0-cp38-cp38-win_amd64.whl (33.7 MB)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\nicho\anaconda3\lib\site-packages (from scipy) (1.21.1)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.6.2
#     Uninstalling scipy-1.6.2:
#       Successfully uninstalled scipy-1.6.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\nicho\\anaconda3\\Lib\\site-packages\\~cipy\\fft\\_pocketfft\\pypocketfft.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
Precip = 'cru_ts4.05.2001.2010.pre.dat.nc.gz'

precipitation_data = xr.open_dataset(Precip)

nepal_rain = precipitation_data.loc[dict(lat=slice(26,28), lon=slice(80.5,88))]

print(nepal_rain)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 4, lon: 15, time: 120)
# Coordinates:
#   * lon      (lon) float32 80.75 81.25 81.75 82.25 ... 86.25 86.75 87.25 87.75
#   * lat      (lat) float32 26.25 26.75 27.25 27.75
#   * time     (time) datetime64[ns] 2001-01-16 2001-02-15 ... 2010-12-16
# Data variables:
#     pre      (time, lat, lon) float32 ...
#     stn      (time, lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.05 Precipitation
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2103051243. Data generated from:pre.2103041709.dtb
#     history:      Fri  5 Mar 14:41:58 GMT 2021 : User harry : Program makegri...
#     references:   Information on the data is available at http://badc.nerc.ac...
#     comment:      Access to these data is available to any registered CEDA user.
#     contact:      support@ceda.ac.uk

# %%
Chitwan_rain = nepal_rain.loc[dict(lat = 27.75, lon = 84.25 )]

Chitwan_rain
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 120)
# Coordinates:
#     lon      float32 84.25
#     lat      float32 27.75
#   * time     (time) datetime64[ns] 2001-01-16 2001-02-15 ... 2010-12-16
# Data variables:
#     pre      (time) float32 ...
#     stn      (time) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.05 Precipitation
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2103051243. Data generated from:pre.2103041709.dtb
#     history:      Fri  5 Mar 14:41:58 GMT 2021 : User harry : Program makegri...
#     references:   Information on the data is available at http://badc.nerc.ac...
#     comment:      Access to these data is available to any registered CEDA user.
#     contact:      support@ceda.ac.uk

# %%
years = 10 

Precip_annual = np.zeros(years)

for year in range(years):
    
    start_index2 = year * 12
    end_index2 = (year + 1) * 12
    
    Precip_annual[year] = Chitwan_rain['pre'][start_index2:end_index2].mean()
    
    
print(Precip_annual)
np.save('Precip_annual.npy', Precip_annual)
# Out:
# [203.47499084 196.8416748  191.125      207.78334045 142.09165955
#  164.         164.48335266 217.27502441 145.2166748  176.82501221]

# %%
f, ax = plt.subplots()

x = np.arange(2001, 2011, 1)
y = Precip_annual

ax.set_xlabel('Year')
ax.set_ylabel('Mean Annual Precipitation (in MM)')
ax.plot(x, Precip_annual)

#plt.show()
plt.savefig('Precipitation.png')

# %%
Precip2 = 'cru_ts4.05.2011.2020.pre.dat.nc.gz'

precipitation_data2 = xr.open_dataset(Precip2)

nepal_rain2 = precipitation_data2.loc[dict(lat=slice(26,28), lon=slice(80.5,88))]

print(nepal_rain2)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 4, lon: 15, time: 120)
# Coordinates:
#   * lon      (lon) float32 80.75 81.25 81.75 82.25 ... 86.25 86.75 87.25 87.75
#   * lat      (lat) float32 26.25 26.75 27.25 27.75
#   * time     (time) datetime64[ns] 2011-01-16 2011-02-15 ... 2020-12-16
# Data variables:
#     pre      (time, lat, lon) float32 ...
#     stn      (time, lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.05 Precipitation
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2103051243. Data generated from:pre.2103041709.dtb
#     history:      Fri  5 Mar 14:41:58 GMT 2021 : User harry : Program makegri...
#     references:   Information on the data is available at http://badc.nerc.ac...
#     comment:      Access to these data is available to any registered CEDA user.
#     contact:      support@ceda.ac.uk

# %%
Chitwan_rain2 = nepal_rain2.loc[dict(lat = 27.75, lon = 84.25 )]

print(Chitwan_rain2)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 120)
# Coordinates:
#     lon      float32 84.25
#     lat      float32 27.75
#   * time     (time) datetime64[ns] 2011-01-16 2011-02-15 ... 2020-12-16
# Data variables:
#     pre      (time) float32 ...
#     stn      (time) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.05 Precipitation
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2103051243. Data generated from:pre.2103041709.dtb
#     history:      Fri  5 Mar 14:41:58 GMT 2021 : User harry : Program makegri...
#     references:   Information on the data is available at http://badc.nerc.ac...
#     comment:      Access to these data is available to any registered CEDA user.
#     contact:      support@ceda.ac.uk

# %%
years = 10 

Precip_annual2 = np.zeros(years)

for year in range(years):
    
    start_index2 = year * 12
    end_index2 = (year + 1) * 12
    
    Precip_annual2[year] = Chitwan_rain2['pre'][start_index2:end_index2].mean()
    
    
print(Precip_annual2)
np.save('Precip_annual2.npy', Precip_annual2)
# Out:
# [243.88334656 193.55834961 196.52497864  54.6416626  164.40000916
#  184.87498474 159.28334045 188.82501221 146.24998474 181.0166626 ]

# %%
f, ax = plt.subplots()

x = np.arange(2011, 2021, 1)
y = Precip_annual2

ax.set_xlabel('Year')
ax.set_ylabel('Mean Annual Precipitation (in MM)')
ax.plot(x, Precip_annual2)

plt.show()
